# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
df=pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (2000, 12)

# %%
##check missing values
df.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure                   0
# Level_of_Hemoglobin              0
# Age                              0
# BMI                              0
# Sex                              0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
df.head()
# Out:
#    Patient_Number  Blood_Pressure  Level_of_Hemoglobin  Age  BMI  Sex  \
# 0               1               1                11.28   34   23    1
# 1               2               0                 9.75   54   33    1
# 2               3               1                10.79   70   49    0
# 3               4               0                11.00   71   50    0
# 4               5               1                14.17   52   19    0
#
#    Smoking  Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# 0        0              45961                     48071                2
# 1        0              26106                     25333                3
# 2        0               9995                     29465                2
# 3        0              10635                      7439                1
# 4        0              15619                     49644                2
#
#    Chronic_kidney_disease  Adrenal_and_thyroid_disorders
# ...

# %%
# Renaming DiabetesPedigreeFunction as DPF
df = df.rename(columns={'Level_of_Hemoglobin':'LOHemoglobin'})
df = df.rename(columns={'Blood_Pressure_Abnormality':'BP'})

df = df.rename(columns={'salt_content_in_the_diet':'salt_citd'})
df = df.rename(columns={'Chronic_kidney_disease':'CKD'})

df = df.rename(columns={'Adrenal_and_thyroid_disorders':'ATD'})

# %%
df.head()
# Out:
#    Patient_Number  Blood_Pressure  LOHemoglobin  Age  BMI  Sex  Smoking  \
# 0               1               1         11.28   34   23    1        0
# 1               2               0          9.75   54   33    1        0
# 2               3               1         10.79   70   49    0        0
# 3               4               0         11.00   71   50    0        0
# 4               5               1         14.17   52   19    0        0
#
#    Physical_activity  salt_citd  Level_of_Stress  CKD  ATD
# 0              45961      48071                2    1    1
# 1              26106      25333                3    0    0
# 2               9995      29465                2    1    0
# 3              10635       7439                1    1    0
# 4              15619      49644                2    0    0

# %%
##check missing values
df.isnull().sum()
# Out:
# Patient_Number       0
# Blood_Pressure       0
# LOHemoglobin         0
# Age                  0
# BMI                  0
# Sex                  0
# Smoking              0
# Physical_activity    0
# salt_citd            0
# Level_of_Stress      0
# CKD                  0
# ATD                  0
# dtype: int64

# %%
df.describe()
# Out:
#        Patient_Number  Blood_Pressure  LOHemoglobin          Age          BMI  \
# count     2000.000000     2000.000000   2000.000000  2000.000000  2000.000000
# mean      1000.500000        0.493500     11.710035    46.558500    30.081500
# std        577.494589        0.500083      2.186701    17.107832    11.761208
# min          1.000000        0.000000      8.100000    18.000000    10.000000
# 25%        500.750000        0.000000     10.147500    32.000000    20.000000
# 50%       1000.500000        0.000000     11.330000    46.000000    30.000000
# 75%       1500.250000        1.000000     12.945000    62.000000    40.000000
# max       2000.000000        1.000000     17.560000    75.000000    50.000000
#
#                Sex      Smoking  Physical_activity     salt_citd  \
# count  2000.000000  2000.000000        2000.000000   2000.000000
# mean      0.496000     0.509500       25254.424500  24926.097000
# std       0.500109     0.500035       14015.439623  14211.692586
# ...

# %%
sns.pairplot(df)

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2a9c6c955808> in <module>
#       3 corrmat = df.corr()
#       4 top_corr_features = corrmat.index
# ----> 5 plt.figure(figsize=(20,20))
#       6 #plot heat map
#       7 g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.size
# Out:
# 24000

# %%
df.count()
# Out:
# Patient_Number       2000
# Blood_Pressure       2000
# LOHemoglobin         2000
# Age                  2000
# BMI                  2000
# Sex                  2000
# Smoking              2000
# Physical_activity    2000
# salt_citd            2000
# Level_of_Stress      2000
# CKD                  2000
# ATD                  2000
# dtype: int64

# %%
 # Model Building
from sklearn.model_selection import train_test_split
X = df.drop(columns='Blood_Pressure')
y = df['Blood_Pressure']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
# Creating Random Forest Model
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=20)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
#Creating a pickle file for the classifier
filename = 'bloodpressure-prediction-rfc-model.pkl'
pickle.dump(classifier, open(filename, 'wb'))

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8937c08d392f> in <module>
#       1 # Model Accuracy, how often is the classifier correct?
# ----> 2 print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
y_pred=classifier.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7675
